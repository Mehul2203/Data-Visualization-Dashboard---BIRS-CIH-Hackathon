# %%
# Importing Libraries
import numpy as np # data pre-processing

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px # data visualization
import requests
import pandas as pd
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
from os import path
from PIL import Image
#from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# loading in all the essentials for data manipulation
import pandas as pd
import numpy as np
#load inthe NTLK stopwords to remove articles, preposition and other words that are not actionable
from nltk.corpus import stopwords
# This allows to create individual objects from a bog of words
from nltk.tokenize import word_tokenize
# Lemmatizer helps to reduce words to the base form
from nltk.stem import WordNetLemmatizer
# Ngrams allows to group words in common pairs or trigrams..etc
from nltk import ngrams
# We can use counter to count the objects
from collections import Counter
# This is our visual library
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import requests
import pandas as pd
import numpy as np
import openpyxl

# %matplotlib inline

# Importing Federal Legislation Data
url = "https://goverlytics.p.rapidapi.com/federal-legislation/ca?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
fed_Legislation_json = response.json()
fed_Legislation_dic = dict(fed_Legislation_json)
fed_Legislation_df = pd.json_normalize(fed_Legislation_json['data'])
fed_Legislation_table = fed_Legislation_df
fed_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/federal-legislation/ca?page="
page_num = 2
while fed_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    fed_Legislation_json = response.json()
    fed_Legislation_dic = dict(fed_Legislation_json)
    fed_Legislation_df = pd.json_normalize(fed_Legislation_json['data'])
    fed_Legislation_table = fed_Legislation_table.append(fed_Legislation_df, ignore_index=True)

# Importing Federal Legislator Data
url = "https://goverlytics.p.rapidapi.com/federal-legislators/ca?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
fed_Legislators_json = response.json()
fed_Legislators_dic = dict(fed_Legislators_json)
fed_Legislators_df = pd.json_normalize(fed_Legislators_json['data'])
fed_Legislators_table = fed_Legislators_df
fed_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/federal-legislators/ca?page="
page_num = 2
while fed_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    fed_Legislators_json = response.json()
    fed_Legislators_dic = dict(fed_Legislators_json)
    fed_Legislators_df = pd.json_normalize(fed_Legislators_json['data'])
    fed_Legislators_table = fed_Legislators_table.append(fed_Legislators_df, ignore_index=True)

# Importing Ontario Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/on?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
on_Legislation_json = response.json()
on_Legislation_dic = dict(on_Legislation_json)
on_Legislation_df = pd.json_normalize(on_Legislation_json['data'])
on_Legislation_table = on_Legislation_df
on_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/on?page="
page_num = 2
while on_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    on_Legislation_json = response.json()
    on_Legislation_dic = dict(on_Legislation_json)
    on_Legislation_df = pd.json_normalize(on_Legislation_json['data'])
    on_Legislation_table = on_Legislation_table.append(on_Legislation_df, ignore_index=True)

# Importing Ontario Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/on?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
on_Legislators_json = response.json()
on_Legislators_dic = dict(on_Legislators_json)
on_Legislators_df = pd.json_normalize(on_Legislators_json['data'])
on_Legislators_table = on_Legislators_df
on_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/on?page="
page_num = 2
while on_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    on_Legislators_json = response.json()
    on_Legislators_dic = dict(on_Legislators_json)
    on_Legislators_df = pd.json_normalize(on_Legislators_json['data'])
    on_Legislators_table = on_Legislators_table.append(on_Legislators_df, ignore_index=True)

# Importing Quebec Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/qc?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
qc_Legislation_json = response.json()
qc_Legislation_dic = dict(qc_Legislation_json)
qc_Legislation_df = pd.json_normalize(qc_Legislation_json['data'])
qc_Legislation_table = qc_Legislation_df
qc_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/qc?page="
page_num = 2
while qc_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    qc_Legislation_json = response.json()
    qc_Legislation_dic = dict(qc_Legislation_json)
    qc_Legislation_df = pd.json_normalize(qc_Legislation_json['data'])
    qc_Legislation_table = qc_Legislation_table.append(qc_Legislation_df, ignore_index=True)

# Importing Quebec Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/qc?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
qc_Legislators_json = response.json()
qc_Legislators_dic = dict(qc_Legislators_json)
qc_Legislators_df = pd.json_normalize(qc_Legislators_json['data'])
qc_Legislators_table = qc_Legislators_df
qc_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/qc?page="
page_num = 2
while qc_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    qc_Legislators_json = response.json()
    qc_Legislators_dic = dict(qc_Legislators_json)
    qc_Legislators_df = pd.json_normalize(qc_Legislators_json['data'])
    qc_Legislators_table = qc_Legislators_table.append(qc_Legislators_df, ignore_index=True)

# Importing BC Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/bc?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
bc_Legislation_json = response.json()
bc_Legislation_dic = dict(bc_Legislation_json)
bc_Legislation_df = pd.json_normalize(bc_Legislation_json['data'])
bc_Legislation_table = bc_Legislation_df
bc_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/bc?page="
page_num = 2
while bc_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    bc_Legislation_json = response.json()
    bc_Legislation_dic = dict(bc_Legislation_json)
    bc_Legislation_df = pd.json_normalize(bc_Legislation_json['data'])
    bc_Legislation_table = bc_Legislation_table.append(bc_Legislation_df, ignore_index=True)

# Importing BC Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/bc?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
bc_Legislators_json = response.json()
bc_Legislators_dic = dict(bc_Legislators_json)
bc_Legislators_df = pd.json_normalize(bc_Legislators_json['data'])
bc_Legislators_table = bc_Legislators_df
bc_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/bc?page="
page_num = 2
while bc_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    bc_Legislators_json = response.json()
    bc_Legislators_dic = dict(bc_Legislators_json)
    bc_Legislators_df = pd.json_normalize(bc_Legislators_json['data'])
    bc_Legislators_table = bc_Legislators_table.append(bc_Legislators_df, ignore_index=True)

# Importing AB Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/ab?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
ab_Legislation_json = response.json()
ab_Legislation_dic = dict(ab_Legislation_json)
ab_Legislation_df = pd.json_normalize(ab_Legislation_json['data'])
ab_Legislation_table = ab_Legislation_df
ab_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/ab?page="
page_num = 2
while ab_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    ab_Legislation_json = response.json()
    ab_Legislation_dic = dict(ab_Legislation_json)
    ab_Legislation_df = pd.json_normalize(ab_Legislation_json['data'])
    ab_Legislation_table = ab_Legislation_table.append(ab_Legislation_df, ignore_index=True)

# Importing AB Legislator Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/ab?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
ab_Legislators_json = response.json()
ab_Legislators_dic = dict(ab_Legislators_json)
ab_Legislators_df = pd.json_normalize(ab_Legislators_json['data'])
ab_Legislators_table = ab_Legislators_df
ab_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/ab?page="
page_num = 2
while ab_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    ab_Legislators_json = response.json()
    ab_Legislators_dic = dict(ab_Legislators_json)
    ab_Legislators_df = pd.json_normalize(ab_Legislators_json['data'])
    ab_Legislators_table = ab_Legislators_table.append(ab_Legislators_df, ignore_index=True)

# Importing MB Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/mb?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
mb_Legislation_json = response.json()
mb_Legislation_dic = dict(mb_Legislation_json)
mb_Legislation_df = pd.json_normalize(mb_Legislation_json['data'])
mb_Legislation_table = mb_Legislation_df
mb_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/mb?page="
page_num = 2
while mb_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    mb_Legislation_json = response.json()
    mb_Legislation_dic = dict(mb_Legislation_json)
    mb_Legislation_df = pd.json_normalize(mb_Legislation_json['data'])
    mb_Legislation_table = mb_Legislation_table.append(mb_Legislation_df, ignore_index=True)

# Importing MB Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/mb?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
mb_Legislators_json = response.json()
mb_Legislators_dic = dict(mb_Legislators_json)
mb_Legislators_df = pd.json_normalize(mb_Legislators_json['data'])
mb_Legislators_table = mb_Legislators_df
mb_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/mb?page="
page_num = 2
while mb_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    mb_Legislators_json = response.json()
    mb_Legislators_dic = dict(mb_Legislators_json)
    mb_Legislators_df = pd.json_normalize(mb_Legislators_json['data'])
    mb_Legislators_table = mb_Legislators_table.append(mb_Legislators_df, ignore_index=True)

# Importing SK Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/sk?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
sk_Legislation_json = response.json()
sk_Legislation_dic = dict(sk_Legislation_json)
sk_Legislation_df = pd.json_normalize(sk_Legislation_json['data'])
sk_Legislation_table = sk_Legislation_df
sk_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/sk?page="
page_num = 2
while sk_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    sk_Legislation_json = response.json()
    sk_Legislation_dic = dict(sk_Legislation_json)
    sk_Legislation_df = pd.json_normalize(sk_Legislation_json['data'])
    sk_Legislation_table = sk_Legislation_table.append(sk_Legislation_df, ignore_index=True)

# Importing SK Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/sk?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
sk_Legislators_json = response.json()
sk_Legislators_dic = dict(sk_Legislators_json)
sk_Legislators_df = pd.json_normalize(sk_Legislators_json['data'])
sk_Legislators_table = sk_Legislators_df
sk_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/sk?page="
page_num = 2
while sk_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    sk_Legislators_json = response.json()
    sk_Legislators_dic = dict(sk_Legislators_json)
    sk_Legislators_df = pd.json_normalize(sk_Legislators_json['data'])
    sk_Legislators_table = sk_Legislators_table.append(sk_Legislators_df, ignore_index=True)

# Importing NB Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/nb?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
nb_Legislation_json = response.json()
nb_Legislation_dic = dict(nb_Legislation_json)
nb_Legislation_df = pd.json_normalize(nb_Legislation_json['data'])
nb_Legislation_table = nb_Legislation_df
nb_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/nb?page="
page_num = 2
while nb_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    nb_Legislation_json = response.json()
    nb_Legislation_dic = dict(nb_Legislation_json)
    nb_Legislation_df = pd.json_normalize(nb_Legislation_json['data'])
    nb_Legislation_table = nb_Legislation_table.append(nb_Legislation_df, ignore_index=True)

# Importing NB Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/nb?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
nb_Legislators_json = response.json()
nb_Legislators_dic = dict(nb_Legislators_json)
nb_Legislators_df = pd.json_normalize(nb_Legislators_json['data'])
nb_Legislators_table = nb_Legislators_df
nb_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/nb?page="
page_num = 2
while nb_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    nb_Legislators_json = response.json()
    nb_Legislators_dic = dict(nb_Legislators_json)
    nb_Legislators_df = pd.json_normalize(nb_Legislators_json['data'])
    nb_Legislators_table = nb_Legislators_table.append(nb_Legislators_df, ignore_index=True)

# Importing NS Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/ns?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
ns_Legislation_json = response.json()
ns_Legislation_dic = dict(ns_Legislation_json)
ns_Legislation_df = pd.json_normalize(ns_Legislation_json['data'])
ns_Legislation_table = ns_Legislation_df
ns_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/ns?page="
page_num = 2
while ns_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    ns_Legislation_json = response.json()
    ns_Legislation_dic = dict(ns_Legislation_json)
    ns_Legislation_df = pd.json_normalize(ns_Legislation_json['data'])
    ns_Legislation_table = ns_Legislation_table.append(ns_Legislation_df, ignore_index=True)

# Importing NS Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/ns?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
ns_Legislators_json = response.json()
ns_Legislators_dic = dict(ns_Legislators_json)
ns_Legislators_df = pd.json_normalize(ns_Legislators_json['data'])
ns_Legislators_table = ns_Legislators_df
ns_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/ns?page="
page_num = 2
while ns_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    ns_Legislators_json = response.json()
    ns_Legislators_dic = dict(ns_Legislators_json)
    ns_Legislators_df = pd.json_normalize(ns_Legislators_json['data'])
    ns_Legislators_table = ns_Legislators_table.append(ns_Legislators_df, ignore_index=True)

# Importing NU Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/nu?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
nu_Legislation_json = response.json()
nu_Legislation_dic = dict(nu_Legislation_json)
nu_Legislation_df = pd.json_normalize(nu_Legislation_json['data'])
nu_Legislation_table = nu_Legislation_df
nu_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/nu?page="
page_num = 2
while nu_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    nu_Legislation_json = response.json()
    nu_Legislation_dic = dict(nu_Legislation_json)
    nu_Legislation_df = pd.json_normalize(nu_Legislation_json['data'])
    nu_Legislation_table = nu_Legislation_table.append(nu_Legislation_df, ignore_index=True)

# Importing NU Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/nu?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
nu_Legislators_json = response.json()
nu_Legislators_dic = dict(nu_Legislators_json)
nu_Legislators_df = pd.json_normalize(nu_Legislators_json['data'])
nu_Legislators_table = nu_Legislators_df
nu_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/nu?page="
page_num = 2
while nu_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    nu_Legislators_json = response.json()
    nu_Legislators_dic = dict(nu_Legislators_json)
    nu_Legislators_df = pd.json_normalize(nu_Legislators_json['data'])
    nu_Legislators_table = nu_Legislators_table.append(nu_Legislators_df, ignore_index=True)

# Importing PE Legislation Data
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/pe?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
pe_Legislation_json = response.json()
pe_Legislation_dic = dict(pe_Legislation_json)
pe_Legislation_df = pd.json_normalize(pe_Legislation_json['data'])
pe_Legislation_table = pe_Legislation_df
pe_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/pe?page="
page_num = 2
while pe_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    pe_Legislation_json = response.json()
    pe_Legislation_dic = dict(pe_Legislation_json)
    pe_Legislation_df = pd.json_normalize(pe_Legislation_json['data'])
    pe_Legislation_table = pe_Legislation_table.append(pe_Legislation_df, ignore_index=True)

# Importing PE Legislators Data
url = "https://goverlytics.p.rapidapi.com/division-legislators/ca/pe?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
pe_Legislators_json = response.json()
pe_Legislators_dic = dict(pe_Legislators_json)
pe_Legislators_df = pd.json_normalize(pe_Legislators_json['data'])
pe_Legislators_table = pe_Legislators_df
pe_Legislators_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislators/ca/pe?page="
page_num = 2
while pe_Legislators_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    pe_Legislators_json = response.json()
    pe_Legislators_dic = dict(pe_Legislators_json)
    pe_Legislators_df = pd.json_normalize(pe_Legislators_json['data'])
    pe_Legislators_table = pe_Legislators_table.append(pe_Legislators_df, ignore_index=True)

# Gender Analysis Across All Provinces
data = {'province':  ['British Columbia', 'British Columbia', 'Ontario', 'Ontario', 'Alberta', 'Alberta', 'Saskatchewan', 'Saskatchewan', 'Quebec', 'Quebec', 'Newfoundland and Labrador', 'Newfoundland and Labrador', 'Manitoba', 'Manitoba', 'New Brunswick', 'New Brunswick', 'Nova Scotia', 'Nova Scotia', 'Prince Edward Island', 'Prince Edward Island'],
        'gender': ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F'],
        'Percentage': [57, 42, 60, 38, 70, 28, 70, 27, 55, 44, 72, 18, 71, 26, 68, 26, 45, 28, 73, 26],
        'country': ['Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada', 'Canada'],
       }
new_df = pd.DataFrame(data)

# %%
fig1 = px.treemap(new_df, path=['country', 'province', 'gender'],
                 values='Percentage',
                  color='Percentage',
                 color_continuous_scale='RdYlGn'
                )
fig1.update_layout(title="Percentage of Males & Females participating in Division Legislation for all provinces of Canada", width=1000, height=700)
fig1.data[0].hovertemplate = '%{label}<br>%{value}'
fig1.show()

# %%
# Provinces Participation in Federal Legislation
x = fed_Legislation_table.province_territory.value_counts()
fig2 = px.bar(x[:25],title = "Province Participation in Federal Legislation:")
fig2.data[0].hovertemplate = '%{label}<br>%{value}'
fig2.show()

# %%
fed_legislation_table['tokenized'] = fed_legislation_table.apply(lambda row: nltk.word_tokenize(row['bill_summary']), axis=1)
tokenl1=[]
for i in list(fed_legislation_table['tokenized']):
    tokenl1+=i
tokenl1 = [t.lower() for t in tokenl1]
stop_words = set(stopwords.words('english'))
new_stopwords = ['bill','thing','act', 'assessment','amendment','statute','supply','amends','part','canada','summary','provide','also','enactment',
                'provides','provided','minister','make','purpose','among','person','certain','relation','march','september','limit',
                'administration','authorize','time','year','may','b','provision','c','e','order','code','make','made','day','take','add','thing']
new_stopwords_list = stop_words.union(new_stopwords)
new_stopwords2=['thing','make']
new_stopwords_list = new_stopwords_list.union(new_stopwords2)
tokenl1 =[t for t in tokenl1 if t not in new_stopwords_list]
tokenl1 = [t for t in tokenl1 if t.isalpha()]
lemmatizer = WordNetLemmatizer()
tokenl1 =[lemmatizer.lemmatize(t) for t in tokenl1]
counted = Counter(tokenl1)
word_freq = pd.DataFrame(counted.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
l2=word_freq
#print(l2)
freqlist=list(l2['frequency'])
wordlist=list(l2['word'])

#Building treemap using plotly:
#Building treemap using plotly:
import plotly.express as px
l2=word_freq.head(120)
#print(l2)
fig11 = px.treemap(l2, path=["word"], values="frequency", title = "Word Treemap of Bill Summary")
fig11.data[0].hovertemplate = '%{label}<br>%{value}'
fig11.write_html("federal_word_treemap.html")
fig11.show()

# %%
import plotly.express as px
l3=l2.head(15)
#print(l3)
l3 = l3.sort_values(by=l3.columns[1], ascending=[True])
fig12 = px.bar(l3, x="frequency", y="word", orientation='h',title="Word Count of Bill Summary")
fig12.show()

# %%
#Federal Topic Scatter Plot
import plotly.express as px
#print(fed_legislation_table['province_territory'].unique())
Federal_topic = fed_legislation_table['topic']
topic_dic = dict()
for topic in Federal_topic:
    if len(topic)==0:
        pass
    elif topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
Federal_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
Federal_df = Federal_df.sort_values(by=Federal_df.columns[1], ascending=[False])
Federal_df['ind'] = range(1, len(Federal_df) + 1)
Federal_df
Federal_df1=Federal_df.head(20)
topiclist=list(Federal_df1['topic'])
frequencylist=list(Federal_df1['count'])
indexlist=list(Federal_df1['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig13 = px.scatter(Federal_df1, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)
fig13.update_layout(
    title='Topic Frequency For Federal Legislation',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig13.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig13.show()

# %%
import plotly.express as px

#BC Topic Scatter Plot
url = "https://goverlytics.p.rapidapi.com/division-legislation/ca/bc?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
bc_Legislation_json = response.json()
bc_Legislation_dic = dict(bc_Legislation_json)
bc_Legislation_df = pd.json_normalize(bc_Legislation_json['data'])
bc_Legislation_table = bc_Legislation_df
bc_Legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/division-legislation/ca/bc?page="
page_num = 2
while bc_Legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    bc_Legislation_json = response.json()
    bc_Legislation_dic = dict(bc_Legislation_json)
    bc_Legislation_df = pd.json_normalize(bc_Legislation_json['data'])
    bc_Legislation_table = bc_Legislation_table.append(bc_Legislation_df, ignore_index=True)

BC_topic = bc_Legislation_table['topic']
topic_dic = dict()
for topic in BC_topic:
    if topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
BC_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
BC_df = BC_df.sort_values(by=BC_df.columns[1], ascending=[False])
BC_df['ind'] = range(1, len(BC_df) + 1)
BC_df

topiclist=list(BC_df['topic'])
frequencylist=list(BC_df['count'])
indexlist=list(BC_df['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig14 = px.scatter(BC_df, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)#[i*10 for i in frequencylist])
fig14.update_layout(
    title='Topic Frequency in BC Province',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig14.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig14.show()

# %%
#AB Topic Scatter Plot - has missing values - Converted into "Others"
AB_topic = ab_Legislation_table['topic']
topic_dic = dict()
for topic in AB_topic:
    if len(topic)==0:
        if "others" in topic_dic:
            topic_dic["others"]+=1
        else:
            topic_dic["others"]=1
    elif topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
AB_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
AB_df = AB_df.sort_values(by=AB_df.columns[1], ascending=[False])
AB_df['ind'] = range(1, len(AB_df) + 1)
AB_df

topiclist=list(AB_df['topic'])
frequencylist=list(AB_df['count'])
indexlist=list(AB_df['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig15= px.scatter(AB_df, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)
fig15.update_layout(
    title='Topic Frequency in AB Province',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig15.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig15.show()

# %%
#MB Topic Scatter Plot 
MB_topic = mb_Legislation_table['topic']
topic_dic = dict()
for topic in MB_topic:
    if topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
MB_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
MB_df = MB_df.sort_values(by=MB_df.columns[1], ascending=[False])
MB_df['ind'] = range(1, len(MB_df) + 1)
MB_df

topiclist=list(MB_df['topic'])
frequencylist=list(MB_df['count'])
indexlist=list(MB_df['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig16= px.scatter(MB_df, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)
fig16.update_layout(
    title='Topic Frequency in MB Province',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig16.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig16.show()

# %%
#NB Topic Scatter Plot 
NB_topic = nb_Legislation_table['topic']
topic_dic = dict()
for topic in NB_topic:
    if topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
NB_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
NB_df = NB_df.sort_values(by=NB_df.columns[1], ascending=[False])
NB_df['ind'] = range(1, len(NB_df) + 1)
NB_df

topiclist=list(NB_df['topic'])
frequencylist=list(NB_df['count'])
indexlist=list(NB_df['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig17 = px.scatter(NB_df, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)#[i*10 for i in frequencylist])
fig17.update_layout(
    title='Topic Frequency in NB Province',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig17.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig17.show()

# %%
#NS
NS_topic = ns_Legislation_table['topic']
topic_dic = dict()
for topic in NS_topic:
    if topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
NS_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
NS_df = NS_df.sort_values(by=NS_df.columns[1], ascending=[False])
NS_df['ind'] = range(1, len(NS_df) + 1)
NS_df

topiclist=list(NS_df['topic'])
frequencylist=list(NS_df['count'])
indexlist=list(NS_df['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig18 = px.scatter(NS_df, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)#[i*10 for i in frequencylist])
fig18.update_layout(
    title='Topic Frequency in NS Province',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig18.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig18.show()

# %%
#NU
NU_topic = nu_Legislation_table['topic']
topic_dic = dict()
for topic in NU_topic:
    if topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
NU_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
NU_df = NU_df.sort_values(by=NU_df.columns[1], ascending=[False])
NU_df['ind'] = range(1, len(NU_df) + 1)
NU_df

topiclist=list(NU_df['topic'])
frequencylist=list(NU_df['count'])
indexlist=list(NU_df['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig19 = px.scatter(NU_df, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)#[i*10 for i in frequencylist])
fig19.update_layout(
    title='Topic Frequency in NU Province',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig19.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig19.show()

# %%
#PE
PE_topic = pe_Legislation_table['topic']
topic_dic = dict()
for topic in PE_topic:
    if topic in topic_dic:
        topic_dic[topic] += 1
    else:
        topic_dic[topic] = 1
PE_df = pd.DataFrame(list(topic_dic.items()),columns = ['topic','count'])
PE_df = PE_df.sort_values(by=PE_df.columns[1], ascending=[False])
PE_df['ind'] = range(1, len(PE_df) + 1)
PE_df

topiclist=list(PE_df['topic'])
frequencylist=list(PE_df['count'])
indexlist=list(PE_df['ind'])
text=[]
for i in range(len(topiclist)):
    c=str(topiclist[i])+'<br>count:'+(str(frequencylist[i]))
    text.append(c)
fig20 = px.scatter(PE_df, x="ind", y="count",size="count",
                  log_x=True,
                 size_max=60,
                color=topiclist)#[i*10 for i in frequencylist])
fig20.update_layout(
    title='Topic Frequency in PE Province',
    xaxis=dict(
        title='Topic',
        gridcolor='white',
        type='log',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)')

fig20.update_traces(
    hovertemplate="<br>".join([
        "count: %{y}"
    ])
)
fig20.show()

# %%
import requests
import pandas as pd
url = "https://goverlytics.p.rapidapi.com/federal-legislation/ca?page=1"
querystring = {"include_summary":"true","include_text":"true","include_actions":"true","include_votes":"true"}
headers = {
    'x-rapidapi-host': "goverlytics.p.rapidapi.com",
    'x-rapidapi-key': "9683493469msh237d2eccd560f26p17fef0jsn788326025e1f"
    }
response = requests.request("GET", url, headers=headers, params=querystring)
fed_legislation_json = response.json()
fed_legislation_dic = dict(fed_legislation_json)
fed_legislation_df = pd.json_normalize(fed_legislation_json['data'])
fed_legislation_table = fed_legislation_df
fed_legislation_df.to_excel('fed_legislation.xlsx')
fed_legislation_dic['pagination']['next_url']
url_0 = "https://goverlytics.p.rapidapi.com/federal-legislation/ca?page="
page_num = 2
while fed_legislation_dic['pagination']['next_url']:
    new_url = url_0 + str(page_num)
    page_num += 1
    response = requests.request("GET", new_url, headers=headers, params=querystring)
    fed_legislation_json = response.json()
    fed_legislation_dic = dict(fed_legislation_json)
    fed_legislation_df = pd.json_normalize(fed_legislation_json['data'])
    fed_legislation_table = fed_legislation_table.append(fed_legislation_df, ignore_index=True)
fed_legislation_table = fed_legislation_table[['date_introduced','province_territory']]
fed_legislation_table['year_introduced'] = pd.DatetimeIndex(fed_legislation_table['date_introduced']).year
fed_legislation_table = fed_legislation_table[['province_territory','year_introduced']]
fed_legislation_table['num_bill_introduced'] = 1
fed_legislation_table = fed_legislation_table.dropna(axis=0)
count_bc_2019 = int()
count_bc_2020 = int()
count_bc_2021 = int()
count_qc_2019 = int()
count_qc_2020 = int()
count_qc_2021 = int()
count_on_2019 = int()
count_on_2020 = int()
count_on_2021 = int()
count_ab_2019 = int()
count_ab_2020 = int()
count_ab_2021 = int()
count_sk_2019 = int()
count_sk_2020 = int()
count_sk_2021 = int()
count_nu_2019 = int()
count_nu_2020 = int()
count_nu_2021 = int()
count_mb_2019 = int()
count_mb_2020 = int()
count_mb_2021 = int()
count_nb_2019 = int()
count_nb_2020 = int()
count_nb_2021 = int()
count_ns_2019 = int()
count_ns_2020 = int()
count_ns_2021 = int()
count_pe_2019 = int()
count_pe_2020 = int()
count_pe_2021 = int()
for i in range(0,len(fed_legislation_table)):
    if fed_legislation_table.iloc[i]['province_territory'] == "BC":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_bc_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_bc_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_bc_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "QC":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_qc_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_qc_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_qc_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "ON":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_on_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_on_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_on_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "AB":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_ab_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_ab_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_ab_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "SK":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_sk_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_sk_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_sk_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "NU":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_nu_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_nu_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_nu_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "MB":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_mb_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_mb_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_mb_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "NB":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_nb_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_nb_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_nb_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "NS":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_ns_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_ns_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_ns_2021 +=1
    elif fed_legislation_table.iloc[i]['province_territory'] == "PE":
        if fed_legislation_table.iloc[i]['year_introduced'] == 2019:
            count_pe_2019 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2020:
            count_pe_2020 +=1
        elif fed_legislation_table.iloc[i]['year_introduced'] == 2021:
            count_pe_2021 +=1
df = pd.DataFrame()
df = df.append({'province_territory':'BC', 'year_introduced':2019, 'num_bill_introduced':count_bc_2019}, ignore_index=True)
df = df.append({'province_territory':'BC', 'year_introduced':2020, 'num_bill_introduced':count_bc_2020}, ignore_index=True)
df = df.append({'province_territory':'BC', 'year_introduced':2021, 'num_bill_introduced':count_bc_2021}, ignore_index=True)
df = df.append({'province_territory':'QC', 'year_introduced':2019, 'num_bill_introduced':count_qc_2019}, ignore_index=True)
df = df.append({'province_territory':'QC', 'year_introduced':2020, 'num_bill_introduced':count_qc_2020}, ignore_index=True)
df = df.append({'province_territory':'QC', 'year_introduced':2021, 'num_bill_introduced':count_qc_2021}, ignore_index=True)
df = df.append({'province_territory':'ON', 'year_introduced':2019, 'num_bill_introduced':count_on_2019}, ignore_index=True)
df = df.append({'province_territory':'ON', 'year_introduced':2020, 'num_bill_introduced':count_on_2020}, ignore_index=True)
df = df.append({'province_territory':'ON', 'year_introduced':2021, 'num_bill_introduced':count_on_2021}, ignore_index=True)
df = df.append({'province_territory':'AB', 'year_introduced':2019, 'num_bill_introduced':count_ab_2019}, ignore_index=True)
df = df.append({'province_territory':'AB', 'year_introduced':2020, 'num_bill_introduced':count_ab_2020}, ignore_index=True)
df = df.append({'province_territory':'AB', 'year_introduced':2021, 'num_bill_introduced':count_ab_2021}, ignore_index=True)
df = df.append({'province_territory':'SK', 'year_introduced':2019, 'num_bill_introduced':count_sk_2019}, ignore_index=True)
df = df.append({'province_territory':'SK', 'year_introduced':2020, 'num_bill_introduced':count_sk_2020}, ignore_index=True)
df = df.append({'province_territory':'SK', 'year_introduced':2021, 'num_bill_introduced':count_sk_2021}, ignore_index=True)
df = df.append({'province_territory':'NU', 'year_introduced':2019, 'num_bill_introduced':count_nu_2019}, ignore_index=True)
df = df.append({'province_territory':'NU', 'year_introduced':2020, 'num_bill_introduced':count_nu_2020}, ignore_index=True)
df = df.append({'province_territory':'NU', 'year_introduced':2021, 'num_bill_introduced':count_nu_2021}, ignore_index=True)
df = df.append({'province_territory':'MB', 'year_introduced':2019, 'num_bill_introduced':count_mb_2019}, ignore_index=True)
df = df.append({'province_territory':'MB', 'year_introduced':2020, 'num_bill_introduced':count_mb_2020}, ignore_index=True)
df = df.append({'province_territory':'MB', 'year_introduced':2021, 'num_bill_introduced':count_mb_2021}, ignore_index=True)
df = df.append({'province_territory':'NB', 'year_introduced':2019, 'num_bill_introduced':count_nb_2019}, ignore_index=True)
df = df.append({'province_territory':'NB', 'year_introduced':2020, 'num_bill_introduced':count_nb_2020}, ignore_index=True)
df = df.append({'province_territory':'NB', 'year_introduced':2021, 'num_bill_introduced':count_nb_2021}, ignore_index=True)
df = df.append({'province_territory':'NS', 'year_introduced':2019, 'num_bill_introduced':count_ns_2019}, ignore_index=True)
df = df.append({'province_territory':'NS', 'year_introduced':2020, 'num_bill_introduced':count_ns_2020}, ignore_index=True)
df = df.append({'province_territory':'NS', 'year_introduced':2021, 'num_bill_introduced':count_ns_2021}, ignore_index=True)
df = df.append({'province_territory':'PE', 'year_introduced':2019, 'num_bill_introduced':count_pe_2019}, ignore_index=True)
df = df.append({'province_territory':'PE', 'year_introduced':2020, 'num_bill_introduced':count_pe_2020}, ignore_index=True)
df = df.append({'province_territory':'PE', 'year_introduced':2021, 'num_bill_introduced':count_pe_2021}, ignore_index=True)
import plotly.express as px
df = df
fig21 = px.bar(df, x="province_territory", y="num_bill_introduced", color="province_territory",
  animation_frame="year_introduced", range_y=[0,60], title="Number of Bill Introduced per Province for 2019-2021")
fig21.show()

# %%
def figures_to_html(figs, filename="dashboard.html"):
    dashboard = open(filename, 'w')
    dashboard.write("<html><head></head><body>" + "\n")
    for fig in figs:
        inner_html = fig.to_html().split('<body>')[1].split('</body>')[0]
        dashboard.write(inner_html)
    dashboard.write("</body></html>" + "\n")
figures_to_html([fig1,fig2,fig11, fig12,fig13,fig14,fig15,fig16,fig17,fig18,fig19,fig20,fig21])
